# %%
from fourier_methods import Fourier
import numpy as np

# %%
fourier = r'C:\Users\edgar1993a\Desktop\fourier.jpg'

# %%
fourier = Fourier()
fourier.set_signal_2d(freqs_1=np.array([10,50,100]))

# %%
fourier.plot_signal_2d()

# %%
fourier.plot_fft2d(freq_map=True)

# %%
###CHIRP

# %%
from four

# %%
ch = Chirp(
    t
)
